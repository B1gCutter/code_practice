# %%
# 41.按位与
print(3 & 5)        # 0011和0101 -> 0001
print(4 & 12)       # 0100和1100 -> 0100(4)
# Out:
# 1
# 4

# %%
# 42.按位或(参加运算的两个数只要两个数中的一个为1，结果就为1)
print(3 | 7)
# Out:
# 7

# %%
# 43.按位异或

# %%
# 44.按位取反

# %%
# 45.计算字符串长度
