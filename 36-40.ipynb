# %%
# 36.有序列表插入数据
list_1 = [1, 3, 5, 7, 9]
num = int(input("输入一个数"))

list_1.append(num)
list_1.sort()
print(list_1)
# Out:
# [1, 2, 3, 5, 7, 9]

# %%
# 37.变量值互换
variable_1 = int(input("给定变量1的值"))
variable_2 = int(input("给定变量2的值"))
variable_1, variable_2 = variable_2, variable_1
print(variable_1, variable_2)
# Out:
# 2 1

# %%
# 38.生成随机数
import random

num = random.randint(1,100)
print(num)
# Out:
# 93

# %%
# 39.lambda表达式
a = lambda x,y:x*y
print(a(2, 3))
# Out:
# 6

# %%
# 40.温度转换
num = input("请输入温度，摄氏度以C结尾，华氏度以F结尾")
if "C" in num:
    print(f"气温是{num}摄氏度")
else:
    print(f"气温是{num}华氏度")
# Out:
# 气温是70F华氏度
